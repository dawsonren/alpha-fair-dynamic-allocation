# %% [markdown]
# # Numerically Showing Unimodality
#
# Randomly generate with random support points, uniform, and Normal, all 20 support points. For uniform, draw a, b from a random distribution, as well as for Normal. Try for 2, 3, and 4-node distributions.
#
# To check unimodality, sample from lambdas [-2, 2], which by Chebyshev's inequality must cover 3/4 of the probability mass of the demand distributions. We check for lambda_time, so there's only one parameter to learn. We check in increments of 0.01, and establish unimodality on our checked points.

# %%
import sys
import random
import os
import random

# add library to path (or else, src not visible)
sys.path.insert(0, "../../")

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from tqdm import tqdm

from src.AllocationSolver import AllocationSolver, lambda_bound
from src.dists import SymmetricDiscreteDistribution, Distribution, UniformDistribution, NormalDistribution
from src.monte_carlo import hoeffding_bound
from src.format_data import clean_data
from src.random_problem import generate_random_problem, generate_general_distribution, generate_normal_distribution, generate_uniform_distribution

# use seaborn style plotting for paper
sns.set_context("paper")
sns.set_style("whitegrid")

# %%
def is_unimodal_sequence(sequence, tol=1e-4):
    """
    Check if a sequence is unimodal

    That is, check if left of the maximum, the sequence is increasing
    and right of the maximum, the sequence is decreasing
    """
    max_index = sequence.index(max(sequence))
    return all(-tol <= sequence[i+1] - sequence[i] for i in range(max_index)) and all(sequence[i] - sequence[i+1] >= -tol for i in range(max_index, len(sequence)-1))

# %% [markdown]
# ## Uniform and Normal Distributions

# %%
random.seed(0)
np.random.seed(0)

num_problems = 1000

for _ in tqdm(range(num_problems)):
    # prob = generate_random_problem(3, generate_normal_distribution((1, 2), random.random() * 0.5, n=5), allocation_method="lambda_time")
    prob = generate_random_problem(3, generate_uniform_distribution((1, 2), 10))
    
    # for alphas = [0.1, 0.2, 0.5, 1, 2, 5, 10]
    for a in [0.1, 0.2, 0.5, 1, 2, 5, 10, np.inf]:
        prob.change_alpha(a)
        # for supply scarcity = [0.1, 0.2 ... 1.9, 2]
        for ss in np.arange(0.1, 2, 0.1):
            prob.change_initial_supply(sum(prob.demand_means) * ss)
            Z_values = []

            # for lambdas = [-2, -1.9, -1.8 ... 1.9, 2]
            for l in np.arange(prob.get_lambda_range()[0], 2, 0.1):
                prob.set_lambda_schedule([l for _ in range(prob.N)])
                Z = prob.solve()[0]
                if Z > 0:
                    Z_values.append(Z)

            if not is_unimodal_sequence(Z_values):
                # print formatted table of lambdas and Z values
                for l, Z in zip(np.arange(-2, 2, 0.1), Z_values):
                    print(f"Lambda: {l:.1f}, Z: {Z:.5f}")
                print(prob)
                print(f"Alpha: {a}, Supply Scarcity: {ss}")
                print(lambda_bound(prob.demand_distributions, lambda_time=True))
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# Lambda: -2.0, Z: 0.18306
# Lambda: -1.9, Z: 0.07523
# Lambda: -1.8, Z: 0.37448
# Lambda: -1.7, Z: 0.00000
# Lambda: -1.6, Z: 0.01763
# Lambda: -1.5, Z: 0.03397
# Lambda: -1.4, Z: 0.04817
# Lambda: -1.3, Z: 0.06008
# Lambda: -1.2, Z: 0.06984
# Lambda: -1.1, Z: 0.07768
# Lambda: -1.0, Z: 0.08388
# Lambda: -0.9, Z: 0.08869
# Lambda: -0.8, Z: 0.09235
# Lambda: -0.7, Z: 0.09505
# Lambda: -0.6, Z: 0.09698
# Lambda: -0.5, Z: 0.09826
# Lambda: -0.4, Z: 0.09902
# Lambda: -0.3, Z: 0.09935
# Lambda: -0.2, Z: 0.09934
# Lambda: -0.1, Z: 0.09905
# Lambda: 0.0, Z: 0.09853
# Lambda: 0.1, Z: 0.09784
# Lambda: 0.2, Z: 0.09700
# Lambda: 0.3, Z: 0.09605
# Lambda: 0.4, Z: 0.09501
# Lambda: 0.5, Z: 0.09391
# Lambda: 0.6, Z: 0.09276
# Lambda: 0.7, Z: 0.09157
# Lambda: 0.8, Z: 0.09035
# Lambda: 0.9, Z: 0.08912
# Lambda: 1.0, Z: 0.08788
# Lambda: 1.1, Z: 0.08665
# Lambda: 1.2, Z: 0.08541
# Lambda: 1.3, Z: 0.08418
# Lambda: 1.4, Z: 0.08297
# Lambda: 1.5, Z: 0.08176
# Lambda: 1.6, Z: 0.08058
# Lambda: 1.7, Z: 0.07941
# Node 0: { 1: 0.5, 2: 0.5 }
# Node 1: { 1: 0.5, 2: 0.5 }
# Node 2: { 1: 0.5, 2: 0.5 }
# Node 3: { 1: 0.5, 2: 0.5 }
# Node 4: { 1: 0.5, 2: 0.5 }
# Alpha: 2, Supply Scarcity: 0.1
# -1.3416407864998738
# Lambda: -2.0, Z: 0.12724
# Lambda: -1.9, Z: 0.29774
# Lambda: -1.8, Z: 0.60712
# Lambda: -1.7, Z: 0.00137
# Lambda: -1.6, Z: 0.01853
# Lambda: -1.5, Z: 0.03874
# Lambda: -1.4, Z: 0.06794
# Lambda: -1.3, Z: 0.09634
# Lambda: -1.2, Z: 0.12017
# Lambda: -1.1, Z: 0.13968
# Lambda: -1.0, Z: 0.15536
# Lambda: -0.9, Z: 0.16776
# Lambda: -0.8, Z: 0.17738
# Lambda: -0.7, Z: 0.18470
# Lambda: -0.6, Z: 0.19011
# Lambda: -0.5, Z: 0.19395
# Lambda: -0.4, Z: 0.19652
# Lambda: -0.3, Z: 0.19803
# Lambda: -0.2, Z: 0.19870
# Lambda: -0.1, Z: 0.19868
# Lambda: 0.0, Z: 0.19810
# Lambda: 0.1, Z: 0.19707
# Lambda: 0.2, Z: 0.19568
# Lambda: 0.3, Z: 0.19400
# Lambda: 0.4, Z: 0.19210
# Lambda: 0.5, Z: 0.19003
# Lambda: 0.6, Z: 0.18782
# Lambda: 0.7, Z: 0.18551
# Lambda: 0.8, Z: 0.18313
# Lambda: 0.9, Z: 0.18070
# Lambda: 1.0, Z: 0.17824
# Lambda: 1.1, Z: 0.17577
# Lambda: 1.2, Z: 0.17329
# Lambda: 1.3, Z: 0.17082
# Lambda: 1.4, Z: 0.16837
# Lambda: 1.5, Z: 0.16593
# Lambda: 1.6, Z: 0.16353
# Lambda: 1.7, Z: 0.16116
# Lambda: 1.8, Z: 0.15882
# Node 0: { 1: 0.5, 2: 0.5 }
# Node 1: { 1: 0.5, 2: 0.5 }
# Node 2: { 1: 0.5, 2: 0.5 }
# Node 3: { 1: 0.5, 2: 0.5 }
# Node 4: { 1: 0.5, 2: 0.5 }
# Alpha: 2, Supply Scarcity: 0.2
# -1.3416407864998738
# Lambda: -2.0, Z: 0.33739
# Lambda: -1.9, Z: 0.55259
# Lambda: -1.8, Z: 0.59117
# Lambda: -1.7, Z: 0.01612
# Lambda: -1.6, Z: 0.03463
# Lambda: -1.5, Z: 0.05652
# Lambda: -1.4, Z: 0.08185
# Lambda: -1.3, Z: 0.11591
# Lambda: -1.2, Z: 0.14592
# Lambda: -1.1, Z: 0.18025
# Lambda: -1.0, Z: 0.20952
# Lambda: -0.9, Z: 0.23304
# Lambda: -0.8, Z: 0.25163
# Lambda: -0.7, Z: 0.26607
# Lambda: -0.6, Z: 0.27704
# Lambda: -0.5, Z: 0.28516
# Lambda: -0.4, Z: 0.29093
# Lambda: -0.3, Z: 0.29477
# Lambda: -0.2, Z: 0.29705
# Lambda: -0.1, Z: 0.29805
# Lambda: 0.0, Z: 0.29802
# Lambda: 0.1, Z: 0.29714
# Lambda: 0.2, Z: 0.29560
# Lambda: 0.3, Z: 0.29352
# Lambda: 0.4, Z: 0.29100
# Lambda: 0.5, Z: 0.28816
# Lambda: 0.6, Z: 0.28504
# Lambda: 0.7, Z: 0.28173
# Lambda: 0.8, Z: 0.27827
# Lambda: 0.9, Z: 0.27470
# Lambda: 1.0, Z: 0.27106
# Lambda: 1.1, Z: 0.26737
# Lambda: 1.2, Z: 0.26364
# Lambda: 1.3, Z: 0.25991
# Lambda: 1.4, Z: 0.25620
# Lambda: 1.5, Z: 0.25251
# Lambda: 1.6, Z: 0.24885
# Lambda: 1.7, Z: 0.24523
# Lambda: 1.8, Z: 0.24166
# Lambda: 1.9, Z: 0.23814
# Node 0: { 1: 0.5, 2: 0.5 }
# Node 1: { 1: 0.5, 2: 0.5 }
# Node 2: { 1: 0.5, 2: 0.5 }
# Node 3: { 1: 0.5, 2: 0.5 }
# Node 4: { 1: 0.5, 2: 0.5 }
# Alpha: 2, Supply Scarcity: 0.30000000000000004
# -1.3416407864998738
#   0%|          | 0/1 [00:05<?, ?it/s]
# Lambda: -2.0, Z: 0.55458
# Lambda: -1.9, Z: 0.59532
# Lambda: -1.8, Z: 0.58745
# Lambda: -1.7, Z: 0.05523
# Lambda: -1.6, Z: 0.09361
# Lambda: -1.5, Z: 0.12677
# Lambda: -1.4, Z: 0.15477
# Lambda: -1.3, Z: 0.18111
# Lambda: -1.2, Z: 0.21435
# Lambda: -1.1, Z: 0.25000
# Lambda: -1.0, Z: 0.27936
# Lambda: -0.9, Z: 0.31072
# Lambda: -0.8, Z: 0.33551
# Lambda: -0.7, Z: 0.35476
# Lambda: -0.6, Z: 0.36939
# Lambda: -0.5, Z: 0.38022
# Lambda: -0.4, Z: 0.38791
# Lambda: -0.3, Z: 0.39303
# Lambda: -0.2, Z: 0.39607
# Lambda: -0.1, Z: 0.39740
# Lambda: 0.0, Z: 0.39735
# Lambda: 0.1, Z: 0.39619
# Lambda: 0.2, Z: 0.39408
# Lambda: 0.3, Z: 0.39125
# Lambda: 0.4, Z: 0.38785
# Lambda: 0.5, Z: 0.38400
# Lambda: 0.6, Z: 0.37977
# Lambda: 0.7, Z: 0.37528
# Lambda: 0.8, Z: 0.37058
# Lambda: 0.9, Z: 0.36573
# Lambda: 1.0, Z: 0.36080
# Lambda: 1.1, Z: 0.35581
# Lambda: 1.2, Z: 0.35077
# Lambda: 1.3, Z: 0.34573
# Lambda: 1.4, Z: 0.34073
# Lambda: 1.5, Z: 0.33575
# Lambda: 1.6, Z: 0.33082
# Lambda: 1.7, Z: 0.32595
# Lambda: 1.8, Z: 0.32116
# Lambda: 1.9, Z: 0.31644
# Node 0: { 1: 0.5, 2: 0.5 }
# Node 1: { 1: 0.5, 2: 0.5 }
# Node 2: { 1: 0.5, 2: 0.5 }
# Node 3: { 1: 0.5, 2: 0.5 }
# Node 4: { 1: 0.5, 2: 0.5 }
# Alpha: 2, Supply Scarcity: 0.4
# -1.3416407864998738
# Lambda: -2.0, Z: 0.62013
# Lambda: -1.9, Z: 0.61671
# Lambda: -1.8, Z: 0.61413
# Lambda: -1.7, Z: 0.15849
# Lambda: -1.6, Z: 0.18699
# Lambda: -1.5, Z: 0.21447
# Lambda: -1.4, Z: 0.24586
# Lambda: -1.3, Z: 0.28140
# Lambda: -1.2, Z: 0.31052
# Lambda: -1.1, Z: 0.33422
# Lambda: -1.0, Z: 0.36427
# Lambda: -0.9, Z: 0.39456
# Lambda: -0.8, Z: 0.41939
# Lambda: -0.7, Z: 0.44345
# Lambda: -0.6, Z: 0.46174
# Lambda: -0.5, Z: 0.47527
# Lambda: -0.4, Z: 0.48488
# Lambda: -0.3, Z: 0.49125
# Lambda: -0.2, Z: 0.49487
# Lambda: -0.1, Z: 0.49640
# Lambda: 0.0, Z: 0.49617
# Lambda: 0.1, Z: 0.49448
# Lambda: 0.2, Z: 0.49165
# Lambda: 0.3, Z: 0.48794
# Lambda: 0.4, Z: 0.48352
# Lambda: 0.5, Z: 0.47848
# Lambda: 0.6, Z: 0.47305
# Lambda: 0.7, Z: 0.46732
# Lambda: 0.8, Z: 0.46132
# Lambda: 0.9, Z: 0.45517
# Lambda: 1.0, Z: 0.44892
# Lambda: 1.1, Z: 0.44260
# Lambda: 1.2, Z: 0.43627
# Lambda: 1.3, Z: 0.42995
# Lambda: 1.4, Z: 0.42366
# Lambda: 1.5, Z: 0.41744
# Lambda: 1.6, Z: 0.41129
# Lambda: 1.7, Z: 0.40522
# Lambda: 1.8, Z: 0.39925
# Lambda: 1.9, Z: 0.39339
# Node 0: { 1: 0.5, 2: 0.5 }
# Node 1: { 1: 0.5, 2: 0.5 }
# Node 2: { 1: 0.5, 2: 0.5 }
# Node 3: { 1: 0.5, 2: 0.5 }
# Node 4: { 1: 0.5, 2: 0.5 }
# Alpha: 2, Supply Scarcity: 0.5
# -1.3416407864998738
# Lambda: -2.0, Z: 0.66697
# Lambda: -1.9, Z: 0.67307
# Lambda: -1.8, Z: 0.67658
# Lambda: -1.7, Z: 0.28985
# Lambda: -1.6, Z: 0.31815
# Lambda: -1.5, Z: 0.34639
# Lambda: -1.4, Z: 0.37691
# Lambda: -1.3, Z: 0.40217
# Lambda: -1.2, Z: 0.42296
# Lambda: -1.1, Z: 0.44625
# Lambda: -1.0, Z: 0.47052
# Lambda: -0.9, Z: 0.49039
# Lambda: -0.8, Z: 0.51374
# Lambda: -0.7, Z: 0.53572
# Lambda: -0.6, Z: 0.55409
# Lambda: -0.5, Z: 0.57004
# Lambda: -0.4, Z: 0.58127
# Lambda: -0.3, Z: 0.58863
# Lambda: -0.2, Z: 0.59263
# Lambda: -0.1, Z: 0.59408
# Lambda: 0.0, Z: 0.59347
# Lambda: 0.1, Z: 0.59108
# Lambda: 0.2, Z: 0.58743
# Lambda: 0.3, Z: 0.58275
# Lambda: 0.4, Z: 0.57720
# Lambda: 0.5, Z: 0.57104
# Lambda: 0.6, Z: 0.56441
# Lambda: 0.7, Z: 0.55744
# Lambda: 0.8, Z: 0.55020
# Lambda: 0.9, Z: 0.54281
# Lambda: 1.0, Z: 0.53532
# Lambda: 1.1, Z: 0.52778
# Lambda: 1.2, Z: 0.52017
# Lambda: 1.3, Z: 0.51258
# Lambda: 1.4, Z: 0.50506
# Lambda: 1.5, Z: 0.49763
# Lambda: 1.6, Z: 0.49026
# Lambda: 1.7, Z: 0.48298
# Lambda: 1.8, Z: 0.47580
# Lambda: 1.9, Z: 0.46876
# Node 0: { 1: 0.5, 2: 0.5 }
# Node 1: { 1: 0.5, 2: 0.5 }
# Node 2: { 1: 0.5, 2: 0.5 }
# Node 3: { 1: 0.5, 2: 0.5 }
# Node 4: { 1: 0.5, 2: 0.5 }
# Alpha: 2, Supply Scarcity: 0.6
# -1.3416407864998738
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 21
#      19 for l in np.arange(prob.get_lambda_range()[0], 2, 0.1):
#      20     prob.set_lambda_schedule([l for _ in range(prob.N)])
# ---> 21     Z = prob.solve()[0]
#      22     if Z > 0:
#      23         Z_values.append(Z)
#
# File ~/Desktop/Research/alpha-fair-dynamic-allocation/src/experiments/../../src/AllocationSolver.py:387, in AllocationSolver.solve(self)
#     381 def solve(self):
#     382     """
#     383     Solves the alpha-fair dynamic allocation problem.
#     384
#     385     Returns the welfare and the waste as a tuple (Z, w)
#     386     """
# --> 387     return self.demand_distributions[0].expect_with_prob(
#     388         lambda d, p: np.array(
#     389             self.evaluate_allocation_policy(1, State(self.initial_supply, d), empty_extra_state())
#     390         )
#     391     )
#
# File ~/Desktop/Research/alpha-fair-dynamic-allocation/src/experiments/../../src/dists.py:40, in Distribution.expect_with_prob(self, f)
#      39 def expect_with_prob(self, f):
# ---> 40     return sum([p * f(x, p) for x, p in zip(self.xk, self.pk)])
#
# File ~/Desktop/Research/alpha-fair-dynamic-allocation/src/experiments/../../src/dists.py:40, in <listcomp>(.0)
#      39 def expect_with_prob(self, f):
# ---> 40     return sum([p * f(x, p) for x, p in zip(self.xk, self.pk)])
#
# File ~/Desktop/Research/alpha-fair-dynamic-allocation/src/experiments/../../src/AllocationSolver.py:389, in AllocationSolver.solve.<locals>.<lambda>(d, p)
#     381 def solve(self):
#     382     """
#     383     Solves the alpha-fair dynamic allocation problem.
#     384
#     385     Returns the welfare and the waste as a tuple (Z, w)
#     386     """
#     387     return self.demand_distributions[0].expect_with_prob(
#     388         lambda d, p: np.array(
# --> 389             self.evaluate_allocation_policy(1, State(self.initial_supply, d), empty_extra_state())
#     390         )
#     391     )
#
# File ~/Desktop/Research/alpha-fair-dynamic-allocation/src/experiments/../../src/AllocationSolver.py:238, in AllocationSolver.evaluate_allocation_policy(self, t, state, extra)
#     236 else:
#     237     x = self.allocation_function(t, state, extra)
# --> 238     Z, w = self.find_welfare_and_waste(t, state, x, extra)
#     240     if self.verbosity >= 1 and extra.verbosity == 1:
#     241         print(
#     242             f"At time {t} with d_t={state.d} and c_t={state.c}, we allocate x_t={x}."
#     243         )
#
# File ~/Desktop/Research/alpha-fair-dynamic-allocation/src/experiments/../../src/AllocationSolver.py:212, in AllocationSolver.find_welfare_and_waste(self, t, state, x, extra)
#     211 def find_welfare_and_waste(self, t, state: State, x, extra: ExtraState):
# --> 212     return self.demand_distributions[t].expect_with_prob(
#     213         lambda d_next, p_next: np.array(
#     214             self.evaluate_allocation_policy(
#     215                 t + 1, state.next_state(x, d_next), extra.next_state(p_next, x, state.d)
#     216             )
#     217         )
#     218     )
#
# File ~/Desktop/Research/alpha-fair-dynamic-allocation/src/experiments/../../src/dists.py:40, in Distribution.expect_with_prob(self, f)
#      39 def expect_with_prob(self, f):
# ---> 40     return sum([p * f(x, p) for x, p in zip(self.xk, self.pk)])
#
# File ~/Desktop/Research/alpha-fair-dynamic-allocation/src/experiments/../../src/dists.py:40, in <listcomp>(.0)
#      39 def expect_with_prob(self, f):
# ---> 40     return sum([p * f(x, p) for x, p in zip(self.xk, self.pk)])
#
# File ~/Desktop/Research/alpha-fair-dynamic-allocation/src/experiments/../../src/AllocationSolver.py:214, in AllocationSolver.find_welfare_and_waste.<locals>.<lambda>(d_next, p_next)
#     211 def find_welfare_and_waste(self, t, state: State, x, extra: ExtraState):
#     212     return self.demand_distributions[t].expect_with_prob(
#     213         lambda d_next, p_next: np.array(
# --> 214             self.evaluate_allocation_policy(
#     215                 t + 1, state.next_state(x, d_next), extra.next_state(p_next, x, state.d)
#     216             )
#     217         )
#     218     )
#
# File ~/Desktop/Research/alpha-fair-dynamic-allocation/src/experiments/../../src/AllocationSolver.py:238, in AllocationSolver.evaluate_allocation_policy(self, t, state, extra)
#     236 else:
#     237     x = self.allocation_function(t, state, extra)
# --> 238     Z, w = self.find_welfare_and_waste(t, state, x, extra)
#     240     if self.verbosity >= 1 and extra.verbosity == 1:
#     241         print(
#     242             f"At time {t} with d_t={state.d} and c_t={state.c}, we allocate x_t={x}."
#     243         )
#
# File ~/Desktop/Research/alpha-fair-dynamic-allocation/src/experiments/../../src/AllocationSolver.py:212, in AllocationSolver.find_welfare_and_waste(self, t, state, x, extra)
#     211 def find_welfare_and_waste(self, t, state: State, x, extra: ExtraState):
# --> 212     return self.demand_distributions[t].expect_with_prob(
#     213         lambda d_next, p_next: np.array(
#     214             self.evaluate_allocation_policy(
#     215                 t + 1, state.next_state(x, d_next), extra.next_state(p_next, x, state.d)
#     216             )
#     217         )
#     218     )
#
# File ~/Desktop/Research/alpha-fair-dynamic-allocation/src/experiments/../../src/dists.py:40, in Distribution.expect_with_prob(self, f)
#      39 def expect_with_prob(self, f):
# ---> 40     return sum([p * f(x, p) for x, p in zip(self.xk, self.pk)])
#
# File ~/Desktop/Research/alpha-fair-dynamic-allocation/src/experiments/../../src/dists.py:40, in <listcomp>(.0)
#      39 def expect_with_prob(self, f):
# ---> 40     return sum([p * f(x, p) for x, p in zip(self.xk, self.pk)])
#
# File ~/Desktop/Research/alpha-fair-dynamic-allocation/src/experiments/../../src/AllocationSolver.py:214, in AllocationSolver.find_welfare_and_waste.<locals>.<lambda>(d_next, p_next)
#     211 def find_welfare_and_waste(self, t, state: State, x, extra: ExtraState):
#     212     return self.demand_distributions[t].expect_with_prob(
#     213         lambda d_next, p_next: np.array(
# --> 214             self.evaluate_allocation_policy(
#     215                 t + 1, state.next_state(x, d_next), extra.next_state(p_next, x, state.d)
#     216             )
#     217         )
#     218     )
#
#     [... skipping similar frames: <lambda> at line 214 (1 times), <listcomp> at line 40 (1 times), evaluate_allocation_policy at line 238 (1 times), Distribution.expect_with_prob at line 40 (1 times), find_welfare_and_waste at line 212 (1 times)]
#
# File ~/Desktop/Research/alpha-fair-dynamic-allocation/src/experiments/../../src/AllocationSolver.py:238, in AllocationSolver.evaluate_allocation_policy(self, t, state, extra)
#     236 else:
#     237     x = self.allocation_function(t, state, extra)
# --> 238     Z, w = self.find_welfare_and_waste(t, state, x, extra)
#     240     if self.verbosity >= 1 and extra.verbosity == 1:
#     241         print(
#     242             f"At time {t} with d_t={state.d} and c_t={state.c}, we allocate x_t={x}."
#     243         )
#
# File ~/Desktop/Research/alpha-fair-dynamic-allocation/src/experiments/../../src/AllocationSolver.py:212, in AllocationSolver.find_welfare_and_waste(self, t, state, x, extra)
#     211 def find_welfare_and_waste(self, t, state: State, x, extra: ExtraState):
# --> 212     return self.demand_distributions[t].expect_with_prob(
#     213         lambda d_next, p_next: np.array(
#     214             self.evaluate_allocation_policy(
#     215                 t + 1, state.next_state(x, d_next), extra.next_state(p_next, x, state.d)
#     216             )
#     217         )
#     218     )
#
# File ~/Desktop/Research/alpha-fair-dynamic-allocation/src/experiments/../../src/dists.py:40, in Distribution.expect_with_prob(self, f)
#      39 def expect_with_prob(self, f):
# ---> 40     return sum([p * f(x, p) for x, p in zip(self.xk, self.pk)])
#
# File ~/Desktop/Research/alpha-fair-dynamic-allocation/src/experiments/../../src/dists.py:40, in <listcomp>(.0)
#      39 def expect_with_prob(self, f):
# ---> 40     return sum([p * f(x, p) for x, p in zip(self.xk, self.pk)])
#
# File ~/Desktop/Research/alpha-fair-dynamic-allocation/src/experiments/../../src/AllocationSolver.py:214, in AllocationSolver.find_welfare_and_waste.<locals>.<lambda>(d_next, p_next)
#     211 def find_welfare_and_waste(self, t, state: State, x, extra: ExtraState):
#     212     return self.demand_distributions[t].expect_with_prob(
#     213         lambda d_next, p_next: np.array(
# --> 214             self.evaluate_allocation_policy(
#     215                 t + 1, state.next_state(x, d_next), extra.next_state(p_next, x, state.d)
#     216             )
#     217         )
#     218     )
#
# File ~/Desktop/Research/alpha-fair-dynamic-allocation/src/experiments/../../src/AllocationSolver.py:230, in AllocationSolver.evaluate_allocation_policy(self, t, state, extra)
#     227 if t == self.N:
#     228     # if we're at the last node
#     229     alloc = min(state.c, state.d)
# --> 230     Z, w = self.social_welfare(np.array(extra.allocations + [alloc]), np.array(extra.demands + [state.d]))[0], max(state.c - state.d, 0)
#     232     if self.verbosity >= 2 and extra.verbosity == 1:
#     233         print(
#     234             f"At time {t} with d_t={state.d} and c_t={state.c}, allocate what's left with Z={round(Z, 4)} and waste={round(w, 4)}."
#     235         )
#
# File ~/Desktop/Research/alpha-fair-dynamic-allocation/src/experiments/../../src/AllocationSolver.py:177, in AllocationSolver.change_alpha.<locals>.<lambda>(allocs, demands)
#     175 def change_alpha(self, alpha):
#     176     # the social welfare function
# --> 177     self.social_welfare = self.social_welfare = lambda allocs, demands: social_welfare_relative(alpha)(allocs[np.newaxis, :], demands[np.newaxis, :])
#     178     self.alpha = alpha
#
# File ~/Desktop/Research/alpha-fair-dynamic-allocation/src/experiments/../../src/metrics.py:31, in social_welfare_relative.<locals>.alpha_relative(allocs, demands)
#      29 def alpha_relative(allocs, demands):
#      30     total_demand = demands.sum(axis=1)
# ---> 31     utilities = np.minimum(allocs / demands, np.ones_like(allocs))
#      32     demand_times_utility = demands * np.power(utilities, 1 - alpha)
#      33     weighted_sum = np.sum(demand_times_utility, axis=1)
#
# File ~/miniconda3/envs/research/lib/python3.11/site-packages/numpy/core/numeric.py:266, in ones_like(a, dtype, order, subok, shape)
#     205 """
#     206 Return an array of ones with the same shape and type as a given array.
#     207
#    (...)
#     263
#     264 """
#     265 res = empty_like(a, dtype=dtype, order=order, subok=subok, shape=shape)
# --> 266 multiarray.copyto(res, 1, casting='unsafe')
#     267 return res
#
# KeyboardInterrupt:
